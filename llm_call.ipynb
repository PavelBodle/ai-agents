# %% [markdown]
# <a href="https://colab.research.google.com/github/PavelBodle/ai-agents/blob/main/llm_call.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google import genai
import os

# %%
# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client(api_key=os.getenv('GEMINI_API_KEY'))

response = client.models.generate_content(
    model="gemini-1.5-flash-preview",
    contents="Explain how AI works in a few words"
)
print(response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-448489832.py in <cell line: 0>()
#       1 # The client gets the API key from the environment variable `GEMINI_API_KEY`.
# ----> 2 client = genai.Client()
#       3
#       4 response = client.models.generate_content(
#       5     model="gemini-1.5-flash-preview",
#
# /usr/local/lib/python3.12/dist-packages/google/genai/client.py in __init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     424         http_options = HttpOptions(base_url=base_url)
#     425
# --> 426     self._api_client = self._get_api_client(
#     427         vertexai=vertexai,
#     428         api_key=api_key,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/client.py in _get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     472       )
# ...

# %%
from google import genai

# %%
client = genai.Client(api_key="AIzaSyADWb5TjkOVPbtJtbxzSRpb67kxuZhYRzc")

# %%
res = client.models.generate_content(
    model="gemini-2.0-flash-lite",
    contents="explain in short AI"

)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipykernel_304/1802351535.py in <cell line: 0>()
# ----> 1 res = client.models.generate_content(
#       2     model="gemini-2.0-flash-lite",
#       3     contents="explain in short AI"
#       4
#       5 )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5707     while remaining_remote_calls_afc > 0:
#    5708       i += 1
# -> 5709       response = self._generate_content(
#    5710           model=model, contents=contents, config=parsed_config
#    5711       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4369     request_dict = _common.encode_unserializable_types(request_dict)
#    4370
# -> 4371     response = self._api_client.request(
# ...

# %%
for model in client.models.list():
    print(model.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# models/gemma-3-27b-it
# models/gemma-3n-e4b-it
# models/gemma-3n-e2b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-2.5-flash-lite-preview-09-2025
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3-pro-image-preview
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-robotics-er-1.5-preview
# models/gemini-2.5-computer-use-preview-10-2025
# ...
